# %% [markdown]
# # I.1 Spatial Data Models
#
# ## What is a Spatial Data Model?
#
# A **spatial data model** is a conceptual framework used to represent real-world geographic features in a structured and organized way. It defines how spatial features are represented, stored, and processed in GIS.
#
# There are two main types of spatial data models:
#
# 1. **Vector data model**
#    Represents geographic features as discrete geometric objects:
#
#    - **Points** (e.g. location of a bus stop)
#    - **Lines** (e.g. roads, rivers)
#    - **Polygons** (e.g. building footprints, administrative boundaries)
#
# 2. **Raster data model**
#    Represents the world as a continuous surface divided into a regular grid of cells (pixels), each containing a value (e.g. satellite imagery, elevation data).

# %% [markdown]
# ### Import libraries

# %% [markdown]
# At the start of each module, we will import the libraries needed for specific tasks, along with a short description and a link to the library’s documentation

# %%
import geopandas as gpd
from shapely.geometry import Point, LineString, Polygon

# %% [markdown]
# - [**GeoPandas**](https://geopandas.org/) (`geopandas`) — an extension of pandas that makes working with geospatial data easy. It allows you to read, manipulate, and analyze spatial datasets in various formats.
#
# - [**Shapely**](https://shapely.readthedocs.io/) (`shapely.geometry`) — a library for creating and working with geometric objects like Points, LineStrings, and Polygons

# %% [markdown]
# ## Vector Data

# %% [markdown]
# In this section, we’ll explore how vector data is structured, how to create and manipulate it using Python
#
# Geometric objects are built from coordinate tuples and come in several basic types:
#
# - A **Point** represents a single location in space, defined by either two (x, y) or three (x, y, z) coordinates.
# - A **LineString** represents a continuous line made up of at least two connected points, forming a path.
# - A **Polygon** defines an enclosed area using a minimum of three coordinate tuples that form the outer boundary (also known as the exterior ring). It can also include one or more interior rings (holes).
#
# In addition to these simple geometries, there are also **collections of geometries**, used when multiple shapes are grouped together:
#
# - A **MultiPoint** is a set of individual points.
# - A **MultiLineString** is a group of LineStrings, each made of connected points.
# - A **MultiPolygon** consists of multiple polygons, each with its own outer boundary and optionally inner holes.

# %% [markdown]
# ### Points
#
# Points represent features that have a specific location but no area or length. For example, a single tree, a bus stop, or a measurement station.
#
# Let's create a point based on known coordinates - longitude and latitude

# %%
# Defining the coordinates
long = 30.336389
lat = 59.931667

# Creating a Point
point = Point(30.336389, 59.931667)

#Looking at the result
print(point)
print(type(point))
display(point)
# Out:
# POINT (30.336389 59.931667)
# <class 'shapely.geometry.point.Point'>
# <POINT (30.336 59.932)>

# %% [markdown]
# The `Point` object we see is from **Shapely**, and it follows a format based on the **GEOS** library — the geometry engine behind many GIS tools such as PostGIS and QGIS.
#
# While a `Point` on its own simply represents a location in space, we can make it much more useful by turning it into a **GeoDataFrame** using the **GeoPandas** library.
#
# A **GeoDataFrame** is an extension of a regular pandas DataFrame that includes a special `geometry` column for storing geometric objects. It allows us to store not only the spatial coordinates, but also additional **attributes** (such as name, type, or ID)

# %%
# creating additional attributes
data = {
    'name': ['Alexandrinsky Theatre'],
    'type': ['Theatre'],
    'geometry': [point]
}

# creating geodataframe, identifiying coordinate reference system
gdf = gpd.GeoDataFrame(data, crs="EPSG:4326")

# looking at the result
print(type(gdf))
gdf
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
#                     name     type                   geometry
# 0  Alexandrinsky Theatre  Theatre  POINT (30.33639 59.93167)

# %% [markdown]
# The data format does indeed resemble a regular DataFrame, but there's one key difference: it includes a special **geometry** column. This column defines the **spatial location** of each object, making it possible to perform geographic operations.

# %% [markdown]
# Let’s display the point on a map using the `explore()` method.
# To make sure it works correctly, you need to have the following libraries installed:
#
# - **folium** – for rendering interactive web maps
# - **mapclassify** – used for classifying data (e.g. color scales, legends)

# %%
# display the result on an interactive map
gdf.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f5c07145bb22ad046da42ee21461f20b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f5c07145bb22ad046da42ee21461f20b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f5c07145bb22ad046da42ee21461f20b = L.map(
#                 &quot;map_f5c07145bb22ad046da42ee21461f20b&quot;,
#                 {
#                     center: [59.931667, 30.336389],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_f5c07145bb22ad046da42ee21461f20b);
#
#
#
#
#
#             var tile_layer_397e9a151a65b759f7b71d18621287dc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f5c07145bb22ad046da42ee21461f20b);
#
#
#             map_f5c07145bb22ad046da42ee21461f20b.fitBounds(
#                 [[59.931667, 30.336389], [59.931667, 30.336389]],
#                 {}
#             );
#
#
#         function geo_json_06c29c4f300af3f1e05128e2270b717a_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_06c29c4f300af3f1e05128e2270b717a_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_06c29c4f300af3f1e05128e2270b717a_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_06c29c4f300af3f1e05128e2270b717a_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_06c29c4f300af3f1e05128e2270b717a_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_06c29c4f300af3f1e05128e2270b717a.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_06c29c4f300af3f1e05128e2270b717a_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_06c29c4f300af3f1e05128e2270b717a = L.geoJson(null, {
#                 onEachFeature: geo_json_06c29c4f300af3f1e05128e2270b717a_onEachFeature,
#
#                 style: geo_json_06c29c4f300af3f1e05128e2270b717a_styler,
#                 pointToLayer: geo_json_06c29c4f300af3f1e05128e2270b717a_pointToLayer
#         });
#
#         function geo_json_06c29c4f300af3f1e05128e2270b717a_add (data) {
#             geo_json_06c29c4f300af3f1e05128e2270b717a
#                 .addData(data)
#                 .addTo(map_f5c07145bb22ad046da42ee21461f20b);
#         }
#             geo_json_06c29c4f300af3f1e05128e2270b717a_add({&quot;bbox&quot;: [30.336389, 59.931667, 30.336389, 59.931667], &quot;features&quot;: [{&quot;bbox&quot;: [30.336389, 59.931667, 30.336389, 59.931667], &quot;geometry&quot;: {&quot;coordinates&quot;: [30.336389, 59.931667], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;name&quot;: &quot;Alexandrinsky Theatre&quot;, &quot;type&quot;: &quot;Theatre&quot;}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#     geo_json_06c29c4f300af3f1e05128e2270b717a.bindTooltip(
#     function(layer){
#     let div = L.DomUtil.create(&#x27;div&#x27;);
#
#     let handleObject = feature=&gt;typ

# %% [markdown]
# Indeed, this is not just a random point with coordinates — it’s **geospatial data**.
# By specifying a coordinate reference system, we know exactly where this object is located in our beautiful world.

# %% [markdown]
# ### Lines
#
# **Lines** represent features that have **length** but no area. They are used to model linear objects such as roads, rivers, or hiking trails — essentially, anything that extends between two or more points.
#
# Since we've already gone through the steps with a point, we'll now go straight to creating a **GeoDataFrame** from a line and visualizing it on a map.

# %%
# defining coordinates
coords_line = [
    (30.308611, 59.9375),   # Field of Mars (left top)
    (30.3125, 59.9390),     # Mikhailovsky Garden
    (30.3185, 59.9405),     # Church of the Savior on Spilled Blood (top center)
    (30.3240, 59.9390),     # Arts Square
    (30.3285, 59.9370),     # Russian Museum area
    (30.3225, 59.9300),     # Kazan Cathedral (bottom right)
    (30.3180, 59.9280),     # Singer House (bottom tip)
    (30.3135, 59.9300),     # Nevsky & Malaya Sadovaya
    (30.308611, 59.9375)    # Back to Field of Mars (close loop)
]

# creating a linestring
line = LineString(coords_line)

gdf_line = gpd.GeoDataFrame([{'geometry': line}], crs="EPSG:4326")

gdf_line.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5e442658f098e2bee2827153558474ab {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5e442658f098e2bee2827153558474ab&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5e442658f098e2bee2827153558474ab = L.map(
#                 &quot;map_5e442658f098e2bee2827153558474ab&quot;,
#                 {
#                     center: [59.93425, 30.3185555],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_5e442658f098e2bee2827153558474ab);
#
#
#
#
#
#             var tile_layer_04521c29c478719a47a5fc02f70d4419 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5e442658f098e2bee2827153558474ab);
#
#
#             map_5e442658f098e2bee2827153558474ab.fitBounds(
#                 [[59.928, 30.308611], [59.9405, 30.3285]],
#                 {}
#             );
#
#
#         function geo_json_8602f5437912adb9453ff52919d1ea26_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_8602f5437912adb9453ff52919d1ea26_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_8602f5437912adb9453ff52919d1ea26_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_8602f5437912adb9453ff52919d1ea26_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_8602f5437912adb9453ff52919d1ea26_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_8602f5437912adb9453ff52919d1ea26.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_8602f5437912adb9453ff52919d1ea26_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_8602f5437912adb9453ff52919d1ea26 = L.geoJson(null, {
#                 onEachFeature: geo_json_8602f5437912adb9453ff52919d1ea26_onEachFeature,
#
#                 style: geo_json_8602f5437912adb9453ff52919d1ea26_styler,
#                 pointToLayer: geo_json_8602f5437912adb9453ff52919d1ea26_pointToLayer
#         });
#
#         function geo_json_8602f5437912adb9453ff52919d1ea26_add (data) {
#             geo_json_8602f5437912adb9453ff52919d1ea26
#                 .addData(data)
#                 .addTo(map_5e442658f098e2bee2827153558474ab);
#         }
#             geo_json_8602f5437912adb9453ff52919d1ea26_add({&quot;bbox&quot;: [30.308611, 59.928, 30.3285, 59.9405], &quot;features&quot;: [{&quot;bbox&quot;: [30.308611, 59.928, 30.3285, 59.9405], &quot;geometry&quot;: {&quot;coordinates&quot;: [[30.308611, 59.9375], [30.3125, 59.939], [30.3185, 59.9405], [30.324, 59.939], [30.3285, 59.937], [30.3225, 59.93], [30.318, 59.928], [30.3135, 59.93], [30.308611, 59.9375]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#     geo_json_8602f5437912adb9453ff52919d1ea26.bindTooltip(
#     function(layer){
#     let div = L.DomUtil.create(&#x27;div&#x27;

# %% [markdown]
# ### Polygons
#
# **Polygons** represent features that have both **area and boundaries**. They are used to model enclosed spaces such as buildings, parks, lakes, districts, and other geographic regions. A polygon is defined by a sequence of coordinates that form a closed ring — the first and last points must be the same.
#
# Since we’ve already created a line from real landmarks in Saint Petersburg, let’s now turn those same coordinates into a **Polygon**, create a **GeoDataFrame**, and visualize it on a map.

# %%
# creating a polygon
polygon =  Polygon(coords_line)

gdf_polygon = gpd.GeoDataFrame([{'geometry': polygon}], crs="EPSG:4326")

gdf_polygon.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f41261743e5ad7c9181ddbd987d0d720 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f41261743e5ad7c9181ddbd987d0d720&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f41261743e5ad7c9181ddbd987d0d720 = L.map(
#                 &quot;map_f41261743e5ad7c9181ddbd987d0d720&quot;,
#                 {
#                     center: [59.93425, 30.3185555],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_f41261743e5ad7c9181ddbd987d0d720);
#
#
#
#
#
#             var tile_layer_7c07bf724d0af3f415ee8da7e27e851f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f41261743e5ad7c9181ddbd987d0d720);
#
#
#             map_f41261743e5ad7c9181ddbd987d0d720.fitBounds(
#                 [[59.928, 30.308611], [59.9405, 30.3285]],
#                 {}
#             );
#
#
#         function geo_json_0814b767c182f97c992e26886fe8f06e_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_0814b767c182f97c992e26886fe8f06e_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_0814b767c182f97c992e26886fe8f06e_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_0814b767c182f97c992e26886fe8f06e_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_0814b767c182f97c992e26886fe8f06e_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_0814b767c182f97c992e26886fe8f06e.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_0814b767c182f97c992e26886fe8f06e_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_0814b767c182f97c992e26886fe8f06e = L.geoJson(null, {
#                 onEachFeature: geo_json_0814b767c182f97c992e26886fe8f06e_onEachFeature,
#
#                 style: geo_json_0814b767c182f97c992e26886fe8f06e_styler,
#                 pointToLayer: geo_json_0814b767c182f97c992e26886fe8f06e_pointToLayer
#         });
#
#         function geo_json_0814b767c182f97c992e26886fe8f06e_add (data) {
#             geo_json_0814b767c182f97c992e26886fe8f06e
#                 .addData(data)
#                 .addTo(map_f41261743e5ad7c9181ddbd987d0d720);
#         }
#             geo_json_0814b767c182f97c992e26886fe8f06e_add({&quot;bbox&quot;: [30.308611, 59.928, 30.3285, 59.9405], &quot;features&quot;: [{&quot;bbox&quot;: [30.308611, 59.928, 30.3285, 59.9405], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[30.308611, 59.9375], [30.3125, 59.939], [30.3185, 59.9405], [30.324, 59.939], [30.3285, 59.937], [30.3225, 59.93], [30.318, 59.928], [30.3135, 59.93], [30.308611, 59.9375]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#     geo_json_0814b767c182f97c992e26886fe8f06e.bindTooltip(
#     function(layer){
#     let div = L.DomUtil.create(&#x27;div&#x27;)

# %% [markdown]
# ## Summary
#
# In this section, we explored the foundations of **spatial data models**, focusing on the **vector model**.
# We learned how real-world geographic features can be represented as **points**, **lines**, and **polygons**, and how to work with these geometries using Python libraries like **Shapely** and **GeoPandas**.
#
# You now know how to:
#
# - Create basic geometric objects from coordinates
# - Store them in a GeoDataFrame
# - Enrich them with attributes and visualize them on a map
